# %%
import plotly
plotly.__version__
# Out:
# '3.4.1'

# %%
import plotly.plotly as py
from plotly.grid_objs import Grid, Column
from plotly.tools import FigureFactory as FF 

import pandas as pd
import time
plotly.tools.set_credentials_file(username='zhangbojian', api_key='XwpQW8S5WmLaOiLTTQIr')
f = pd.read_csv('USA.csv')

# %%
dataset=f

# %%
dataset
# Out:
#           Country  Year  Average of Age  Average of Weight  Average of Height  \
# 0     Afghanistan  1936           24.27                NaN                NaN
# 1     Afghanistan  1948             NaN                NaN                NaN
# 2     Afghanistan  1956             NaN                NaN                NaN
# 3     Afghanistan  1960           23.31              69.44             170.69
# 4     Afghanistan  1964           22.00              64.25             161.00
# 5     Afghanistan  1968           23.20              70.00             170.20
# 6     Afghanistan  1972           29.00              63.75             168.33
# 7     Afghanistan  1980           23.64              63.18             168.36
# 8     Afghanistan  1988             NaN                NaN                NaN
# 9     Afghanistan  1996           23.50                NaN                NaN
# 10    Afghanistan  2004           18.60              64.75             170.75
# ...

# %%
years_from_col = set(dataset['Year'])
years_ints = sorted(list(years_from_col))
years = [str(year) for year in years_ints]
#years.remove('1957')

# make list of continents
continents = []
for continent in dataset['Continent']:
    if continent not in continents: 
        continents.append(continent)

columns = []
# make grid
for year in years:
    for continent in continents:
        dataset_by_year = dataset[dataset['Year'] == int(year)]
        dataset_by_year_and_cont = dataset_by_year[dataset_by_year['Continent'] == continent]
        for col_name in dataset_by_year_and_cont:
            # each column name is unique
            column_name = '{year}_{continent}_{header}_gapminder_grid'.format(
                year=year, continent=continent, header=col_name
            )
            a_column = Column(list(dataset_by_year_and_cont[col_name]), column_name)
            columns.append(a_column)

# upload grid
grid = Grid(columns)
url = py.grid_ops.upload(grid, 'gapminder_grid'+str(time.time()), auto_open=False)
url
# Out:
# 'https://plot.ly/~zhangbojian/27/'

# %%
figure = {
    'data': [],
    'layout': {},
    'frames': [],
    'config': {'scrollzoom': True}
}

# fill in most of layout
figure['layout']['xaxis'] = {'range': [150, 200], 'title': 'Average of Height', 'gridcolor': '#FFFFFF'}
figure['layout']['yaxis'] = {'range': [40, 150],'title': 'Average of Weight', 'gridcolor': '#FFFFFF'}
figure['layout']['hovermode'] = 'closest'
figure['layout']['plot_bgcolor'] = 'rgb(223, 232, 243)'

# %%
figure['layout']['sliders'] = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'text-before-value-on-display',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': [...]
}

# %%
{
    'method': 'animate',
    'label': 'label-for-frame',
    'value': 'value-for-frame(defaults to label)',
    'args': [{'frame': {'duration': 300, 'redraw': False},
         'mode': 'immediate'}
    ],
}
# Out:
# {'args': [{'frame': {'duration': 300, 'redraw': False}, 'mode': 'immediate'}],
#  'label': 'label-for-frame',
#  'method': 'animate',
#  'value': 'value-for-frame(defaults to label)'}

# %%
sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Year:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': []
}

# %%
figure['layout']['updatemenus'] = [
    {
        'buttons': [
            {
                'args': [None, {'frame': {'duration': 500, 'redraw': False},
                         'fromcurrent': True, 'transition': {'duration': 300, 'easing': 'quadratic-in-out'}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration': 0, 'redraw': False}, 'mode': 'immediate',
                'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
]

custom_colors = {
    'Asia': 'rgb(171, 99, 250)',
    'Europe': 'rgb(230, 99, 250)',
    'Africa': 'rgb(99, 110, 250)',
    'Oceania': 'rgb(25, 211, 243)',
    'North America': 'rgb(50, 170, 255)',
    'South America': 'rgb(150, 70, 255)'
}

# %%
col_name_template = '{year}_{continent}_{header}_gapminder_grid'
year = 1896
for continent in continents:
    data_dict = {
        'xsrc': grid.get_column_reference(col_name_template.format(
            year=year, continent=continent, header='Average of Height'
        )),
        'ysrc': grid.get_column_reference(col_name_template.format(
            year=year, continent=continent, header='Average of Weight'
        )),
        'mode': 'markers',
        'textsrc': grid.get_column_reference(col_name_template.format(
            year=year, continent=continent, header='Country'
        )),
        'marker': {
            'sizemode': 'area',
            'sizeref': 0.2,
            'sizesrc': grid.get_column_reference(col_name_template.format(
                 year=year, continent=continent, header='Average of Age'
            )),
            'color': custom_colors[continent]
        },
        'name': continent
    }
    figure['data'].append(data_dict)

# %%
figure['layout']['sliders'] = [sliders_dict]

# %%
for year in years:
    frame = {'data': [], 'name': str(year)}
    for continent in continents:
        data_dict = {
            'xsrc': grid.get_column_reference(col_name_template.format(
                year=year, continent=continent, header='Average of Height'
            )),
            'ysrc': grid.get_column_reference(col_name_template.format(
                year=year, continent=continent, header='Average of Weight'
            )),
            'mode': 'markers',
            'textsrc': grid.get_column_reference(col_name_template.format(
                year=year, continent=continent, header='Country'
                )),
            'marker': {
                'sizemode': 'area',
                'sizeref': 0.2,
                'sizesrc': grid.get_column_reference(col_name_template.format(
                    year=year, continent=continent, header='Average of Age'
                )),
                'color': custom_colors[continent]
            },
            'name': continent
        }
        frame['data'].append(data_dict)

    figure['frames'].append(frame)
    slider_step = {'args': [
        [year],
        {'frame': {'duration': 300, 'redraw': False},
         'mode': 'immediate',
       'transition': {'duration': 300}}
     ],
     'label': year,
     'method': 'animate'}
    sliders_dict['steps'].append(slider_step)

figure['layout']['sliders'] = [sliders_dict]

# %%
py.icreate_animations(figure, 'gapminder_example'+str(time.time()))
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~zhangbojian/28.embed" height="525px" width="100%"></iframe>
